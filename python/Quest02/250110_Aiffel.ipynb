# %% [markdown]
# <a href="https://colab.research.google.com/github/kindcham/AIFFEL_quest-cr/blob/main/python/Quest02/250110_Aiffel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 홍지수) 7번까지 다 했는데 8번에서 시간이 촉박하여 완성하지 못했습니다. 피어 프로그래밍 끝나고 다시 완성해서 마무리 해보겠습니다! 하지만 원미님이랑 같이 설명하면서 코딩하니까 저도 몰랐던 개념들이 더 이해가 잘 되는 것 같아요.

# %% [markdown]
# 최원미) 1~4까지는 단순한 편이라 이해하기 쉬웠는데 5번부터는 내가 딕셔너리와 리스트의 차이를 명확하게 이해하고 있지 못하다는 것을 알게됐다. 리스트는 요소의 나열이고 딕셔너리는 키와 밸류값이 쌍을 이루고있다는 개념만 알 뿐 코딩에 적절히 활용할 능력이 많이 부족한것 같다.

# %% [markdown]
# # 로직
# 1. 파일 불러온다.
# 2. 소문자 변환 -> lower()
# 3. 기호 제거 -> 정규표현식
# 4. 단어 단위로 분리 -> 띄어쓰기를 기준으로 분리
#
# 5. 빈도수 체크 -> 존재하는 단어는 +=1, 존재하지 않는 단어는 =1
# 6. 딕셔너리를 밸류 기준으로 내림차순한다 (lambda)
# 7. 정렬 순서대로 딕셔너리에 키를 뽑아서 인덱스 값을 새로운 밸류로 할당한다
# 8. input값을 받는 함수를 만든다

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import re

def vocabToDigit(text):
  lower_text = text.lower().replace('\n', '') # 소문자 변환 -> lower(), new line -> 제거
  cleaned_text = re.sub(r'[^a-zA-Z0-9\s]', '', lower_text) # 기호 제거 -> 정규표현식 사용
  vocab = cleaned_text.split(' ')

  count = dict()
  for word in vocab: # 빈도수 체크 -> 존재하는 단어는 +=1, 존재하지 않는 단어는 =1
    if word in count:
      count[word] += 1
    else:
      count[word] = 1

  sorted_count = sorted(count.items(), key= lambda item:item[1], reverse=True) # 딕셔너리를 밸류 기준으로 내림차순


  # 정렬 순서대로 딕셔너리에 키를 뽑아서 인덱스 값을 새로운 밸류로 할당한다.
  # sorted_count의 value를 0,1,2,..인덱스로 바꾼다.
  result = dict()
  for index, (key, value) in enumerate(sorted_count):
    result[key] = index

  digit_sequence = [result[word] for word in vocab] # 해당 로직에서 오류

  return digit_sequence

# %%
# 파일 불러온다.

f = open('/content/drive/MyDrive/Colab Notebooks/Avengers.txt', "r")
data = f.read()
print(data)

# %%
user_input = input("Enter a word to search: ").lower()
digit_sequence = vocabToDigit(data) # 구현만 했고 로직 오류 발생합니다!
print(digit_sequence)
# Out:
# Enter a word to search: I am a boy
# [0, 47, 72, 674, 6, 8, 3, 675, 73, 3, 423, 676, 424, 23, 677, 77, 678, 149, 23, 193, 62, 7, 48, 135, 40, 679, 219, 2, 255, 13, 77, 220, 77, 318, 40, 680, 73, 40, 16, 41, 13, 0, 425, 681, 0, 256, 18, 38, 48, 28, 65, 682, 319, 6, 683, 0, 426, 194, 10, 29, 684, 170, 320, 39, 118, 685, 54, 0, 47, 686, 687, 688, 56, 689, 170, 2, 321, 0, 322, 690, 323, 691, 11, 19, 323, 195, 9, 0, 324, 692, 693, 51, 694, 325, 695, 21, 0, 150, 427, 696, 119, 170, 326, 151, 11, 80, 10, 697, 0, 698, 152, 2, 26, 327, 699, 67, 16, 428, 9, 0, 196, 429, 700, 701, 702, 257, 703, 67, 81, 55, 2, 97, 78, 2, 704, 10, 70, 221, 0, 430, 705, 153, 12, 16, 3, 706, 431, 707, 30, 1, 2, 120, 197, 7, 708, 6, 7, 107, 3, 709, 74, 710, 711, 98, 63, 0, 73, 712, 40, 432, 63, 222, 11, 713, 2, 714, 715, 25, 0, 716, 717, 121, 718, 5, 258, 259, 8, 3, 719, 13, 720, 194, 52, 42, 721, 2, 22, 136, 260, 6, 66, 122, 10, 20, 14, 433, 47, 6, 722, 6, 7, 328, 2, 16, 723, 23, 12, 434, 83, 724, 47, 6, 12, 88, 725, 726, 329, 171, 1, 321, 0, 727, 39, 118, 728, 10, 198, 84, 0, 108, 330, 729, 11, 78, 8, 49, 330, 730, 731, 435, 436, 437, 14, 15, 136, 732, 118, 54, 223, 10, 29, 17, 0, 733, 734, 21, 224, 54, 735, 736, 737, 84, 738, 739, 740, 438, 427, 5, 225, 741, 38, 16, 742, 123, 743, 744, 37, 9, 41, 745, 63, 746, 137, 747, 2, 331, 439, 1, 15, 748, 62, 1, 749, 3, 199, 440, 8, 172, 4, 38, 109, 200, 54, 3, 750, 21, 1, 261, 122, 7, 154, 441, 15, 124, 84, 136, 23, 751, 752, 79, 52, 155, 753, 754, 6, 755, 756, 31, 757, 66, 24, 156, 758, 194, 11, 323, 83, 15, 138, 83, 15, 138, 3, 110, 5, 223, 79, 138, 5, 0, 759, 0, 110, 6, 3, 760, 2, 0, 99, 138, 5, 223, 74, 0, 761, 226, 54, 762, 763, 332, 68, 80, 0, 764, 17, 3, 765, 29, 4, 139, 30, 7, 15, 201, 17, 2, 26, 156, 766, 333, 11, 125, 100, 52, 126, 224, 14, 122, 767, 127, 69, 5, 157, 13, 4, 127, 768, 42, 334, 769, 69, 442, 5, 770, 17, 31, 443, 42, 27, 771, 772, 72, 31, 443, 42, 3, 773, 1, 444, 2, 335, 8, 71, 4, 52, 42, 445, 774, 5, 3, 73, 89, 336, 336, 54, 775, 446, 6, 447, 337, 776, 1, 777, 7, 9, 27, 778, 40, 20, 779, 1, 111, 338, 4, 173, 780, 1, 90, 0, 99, 781, 260, 86, 6, 782, 262, 6, 45, 2, 783, 3, 339, 448, 5, 449, 784, 227, 2, 785, 71, 33, 0, 786, 5, 787, 19, 24, 788, 74, 0, 158, 6, 789, 9, 8, 790, 34, 257, 263, 450, 202, 15, 451, 791, 792, 159, 793, 228, 7, 19, 56, 81, 794, 28, 1, 340, 137, 795, 34, 0, 47, 452, 11, 796, 97, 31, 31, 31, 203, 203, 797, 798, 799, 800, 30, 2, 801, 260, 86, 229, 28, 1, 802, 47, 6, 42, 0, 803, 804, 17, 160, 80, 805, 140, 5, 160, 139, 806, 20, 58, 230, 807, 0, 808, 453, 91, 121, 454, 809, 12, 810, 811, 341, 14, 7, 812, 455, 813, 26, 78, 2, 814, 6, 3, 435, 815, 5, 74, 82, 10, 21, 83, 816, 28, 10, 817, 141, 818, 28, 12, 91, 2, 138, 819, 91, 2, 20, 820, 11, 2, 821, 22, 1, 822, 16, 200, 823, 1, 824, 19, 825, 7, 10, 40, 28, 826, 264, 456, 142, 7, 3, 827, 457, 828, 342, 829, 830, 831, 54, 0, 832, 833, 834, 51, 3, 174, 835, 4, 265, 836, 28, 12, 30, 837, 838, 57, 7, 10, 175, 839, 840, 141, 841, 23, 231, 1, 153, 17, 2, 842, 11, 843, 458, 266, 844, 229, 845, 846, 847, 0, 848, 849, 199, 2, 1, 850, 851, 852, 0, 853, 8, 0, 854, 4, 40, 267, 37, 0, 855, 202, 1, 38, 120, 0, 856, 10, 30, 1, 2, 52, 9, 21, 1, 857, 35, 193, 15, 268, 858, 35, 9, 0, 859, 5, 39, 860, 13, 861, 6, 459, 22, 862, 29, 175, 101, 176, 1, 70, 321, 22, 25, 5, 15, 74, 82, 863, 112, 864, 22, 68, 1, 8, 177, 343, 137, 82, 10, 29, 20, 65, 64, 865, 10, 50, 866, 867, 1, 8, 101, 119, 1, 26, 868, 204, 10, 30, 1, 2, 269, 2, 0, 178, 869, 1, 20, 7, 59, 870, 45, 63, 224, 63, 19, 38, 871, 872, 100, 34, 59, 1, 26, 0, 178, 873, 270, 28, 12, 52, 53, 128, 21, 874, 179, 53, 6, 3, 875, 1, 3, 876, 344, 43, 12, 345, 877, 460, 13, 878, 879, 65, 43, 12, 226, 41, 880, 881, 882, 344, 13, 119, 883, 17, 34, 461, 37, 884, 885, 20, 14, 3, 87, 228, 328, 2, 16, 886, 887, 888, 3, 232, 5, 3, 262, 2, 889, 462, 92, 0, 890, 18, 6, 11, 891, 463, 22, 2, 0, 892, 5, 0, 464, 893, 894, 0, 346, 262, 6, 895, 1, 13, 347, 27, 896, 897, 6, 330, 3, 271, 898, 1, 272, 7, 899, 4, 43, 128, 21, 900, 901, 1, 53, 2, 273, 22, 23 ...
