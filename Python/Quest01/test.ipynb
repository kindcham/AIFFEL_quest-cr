# %% [markdown]
# <a href="https://colab.research.google.com/github/kindcham/AIFFEL_quest-cr/blob/main/Python/Quest01/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World")

# %%
print('Hello MODULABS')
